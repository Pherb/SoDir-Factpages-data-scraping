# %% [markdown]
# # 0.0 Notes

# %% [markdown]
# ### Complete:
# - Cross checking the wellbore names in our study area to the wellbore names on SoDir factpages.
# - Parsing the website for each well
# - Scraping **Wellbore history** from each of the wells.
# - Saving the wellbore history text from each well into a single .txt file - This file is called "*wellbore_history.txt*".
# - Fetching the table in **General information** and saves it to a .csv file and a .txt file. Check **sect. 1.4** for this.
#   - This also uses pandas to print the table directly (**NOTE:** This should be excluded when working with larger data sets)
#
# ### Goals:
# - Table with depth (time or meters) gas hydrates
# - Map if there are gas hydrates in the shallow areas --> Only one of the wellbore histories contain the word "*hydrate(s)*", it is found in *34/4-14 S*.
# - top and bottom of reservoir
# - Depth of the main geological feature
# -
# - plot

# %% [markdown]
# # 1.0 Scraping data from a website

# %%
# Importing libraries
import csv
import os
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup, NavigableString, Tag

# %% [markdown]
# ## 1.1 Testing response from website

# %%
# Defining website. Factpages SoDir --> Exploration --> All
url = "https://factpages.sodir.no/en/wellbore/PageView/Exploration/All"

# Checking response from website
response = requests.get(url)
print(response,'if [200], fine')

response = response.content
soup = BeautifulSoup(response, 'html.parser')
# Out:
# <Response [200]> if [200], fine

# %% [markdown]
# ## 1.2 Cross checking wellbore names in our list with wellbore names on SoDir Factpages

# %%
# URL of the webpage to scrape
url = "https://factpages.sodir.no/en/wellbore/PageView/Exploration/All"

# Read wells of interest from a CSV file
wells_of_interest = []
with open('well list.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        wells_of_interest.extend(row)

print("Wellbores in CSV:", len(wells_of_interest))
print("Wellbores found on Factpages:") #, len(well_list))
        
# Fetch the webpage content
response = requests.get(url)
html_content = response.text

# Parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Find all <li> tags
list_items = soup.find_all('li')

# Initialize list to hold the found items
well_list = []

# Iterate through each item
for item in list_items:
    # Extract the text within the <div> tag
    div_text = item.find("div").text if item.find("div") else None
    
    # Check if this text is in your wells_of_interest
    if div_text in wells_of_interest:
        href = item.find("a")["href"] if item.find("a") else None

        well_list.append((div_text, href))

# Determine which wells were not found
not_found_wells = set(wells_of_interest) - set(well[0] for well in well_list)

# Print found items
for name, url in well_list:
    print(f"Well: {name}, URL: {url}")

# Print wells not found
print("\nWells from CSV not found in Factpages:")
for name in not_found_wells:
    print(name)
# Out:
# Wellbores in CSV: 223
# Wellbores found on Factpages:
# Well: 30/2-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/72
# Well: 30/2-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/457
# Well: 30/2-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1970
# Well: 30/2-4 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5784
# Well: 30/2-5 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9051
# Well: 30/3-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/376
# Well: 30/3-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/203
# Well: 30/3-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/10
# Well: 30/3-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/460
# Well: 30/3-9, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4053
# Well: 30/3-10 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6045
# Well: 30/3-11 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9614
# Well: 30/6-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/58
# Well: 30/6-19, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/489
# Well: 30/6-22, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1225
# Well: 30/6-24 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1855
# Well: 30/6-30, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/8569
# Well: 31/1-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5765
# Well: 31/2-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/398
# Well: 31/2-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/227
# Well: 31/2-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/236
# Well: 31/2-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/208
# Well: 31/2-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/210
# Well: 31/2-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/399
# Well: 31/2-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/70
# Well: 31/2-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/78
# Well: 31/2-10, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/90
# Well: 31/2-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6
# Well: 31/2-12, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/14
# Well: 31/2-13 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/93
# Well: 31/2-14, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/106
# Well: 31/2-15, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/439
# Well: 31/2-16 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1453
# Well: 31/2-17 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1898
# Well: 31/2-18, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1988
# Well: 31/2-20 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4636
# Well: 31/2-21 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7416
# Well: 31/3-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/20
# Well: 31/3-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/100
# Well: 31/3-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7292
# Well: 31/5-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/27
# Well: 31/5-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/32
# Well: 31/5-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/101
# Well: 31/5-4 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1689
# Well: 31/5-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2059
# Well: 31/5-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4128
# Well: 31/6-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/22
# Well: 31/6-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/34
# Well: 31/6-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/35
# Well: 31/6-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/404
# Well: 31/6-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/105
# Well: 31/6-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/127
# Well: 31/6-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/141
# Well: 31/6-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/466
# Well: 32/4-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2918
# Well: 33/2-2 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7630
# Well: 33/5-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/103
# Well: 33/5-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/405
# Well: 33/6-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/406
# Well: 33/6-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2873
# Well: 33/6-3 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6835
# Well: 33/6-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6822
# Well: 33/6-5 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9376
# Well: 33/9-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/407
# Well: 33/9-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/409
# Well: 33/9-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/410
# Well: 33/9-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/411
# Well: 33/9-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/412
# Well: 33/9-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/413
# Well: 33/9-9, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/414
# Well: 33/9-10, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/415
# Well: 33/9-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/416
# Well: 33/9-12, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1069
# Well: 33/9-13 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1028
# Well: 33/9-14, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1226
# Well: 33/9-15, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1810
# Well: 33/9-16, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1801
# Well: 33/9-17, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2114
# Well: 33/9-19 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2872
# Well: 33/9-22 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/8248
# Well: 33/12-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/418
# Well: 33/12-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/126
# Well: 33/12-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/115
# Well: 33/12-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/119
# Well: 33/12-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1358
# Well: 33/12-8 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4532
# Well: 33/12-10 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7486
# Well: 34/2-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/420
# Well: 34/2-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/215
# Well: 34/2-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/421
# Well: 34/2-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/467
# Well: 34/2-5 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/8335
# Well: 34/3-2 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6249
# Well: 34/3-3 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6745
# Well: 34/3-4 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7606
# Well: 34/3-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7646
# Well: 34/4-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/422
# Well: 34/4-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/228
# Well: 34/4-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/423
# Well: 34/4-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/41
# Well: 34/4-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/37
# Well: 34/4-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/875
# Well: 34/4-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/943
# Well: 34/4-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1908
# Well: 34/4-9 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2931
# Well: 34/4-10, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3143
# Well: 34/4-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6227
# Well: 34/4-12 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6316
# Well: 34/4-13 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6442
# Well: 34/4-14 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7660
# Well: 34/4-15 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9061
# Well: 34/4-16 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9242
# Well: 34/4-17 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9520
# Well: 34/4-18 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9537
# Well: 34/5-1 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6352
# Well: 34/5-2 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/8448
# Well: 34/7-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/111
# Well: 34/7-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/233
# Well: 34/7-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/442
# Well: 34/7-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/455
# Well: 34/7-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/458
# Well: 34/7-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/465
# Well: 34/7-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/525
# Well: 34/7-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/878
# Well: 34/7-9, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/889
# Well: 34/7-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1176
# Well: 34/7-12, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1187
# Well: 34/7-13, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1233
# Well: 34/7-14, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1278
# Well: 34/7-16, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1550
# Well: 34/7-17, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1713
# Well: 34/7-18, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1819
# Well: 34/7-19, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1838
# Well: 34/7-20, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1967
# Well: 34/7-21, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2026
# Well: 34/7-22, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2167
# Well: 34/7-23 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2326
# Well: 34/7-24 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2460
# Well: 34/7-25 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2863
# Well: 34/7-27, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3214
# Well: 34/7-28, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3282
# Well: 34/7-29 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3313
# Well: 34/7-30 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3757
# Well: 34/7-31, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4214
# Well: 34/7-32, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4423
# Well: 34/7-33, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5917
# Well: 34/7-34, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5973
# Well: 34/10-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/424
# Well: 34/10-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/425
# Well: 34/10-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/426
# Well: 34/10-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/427
# Well: 34/10-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/428
# Well: 34/10-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/429
# Well: 34/10-7, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/222
# Well: 34/10-8, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/230
# Well: 34/10-9, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/140
# Well: 34/10-11, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/211
# Well: 34/10-12, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/204
# Well: 34/10-13, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/431
# Well: 34/10-14, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/95
# Well: 34/10-15, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/67
# Well: 34/10-16, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/59
# Well: 34/10-17, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5
# Well: 34/10-18, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/23
# Well: 34/10-19, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/33
# Well: 34/10-20, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/212
# Well: 34/10-21, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/221
# Well: 34/10-23, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/476
# Well: 34/10-28, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/872
# Well: 34/10-30, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/877
# Well: 34/10-32, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1051
# Well: 34/10-33, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1302
# Well: 34/10-34, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1747
# Well: 34/10-35, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1874
# Well: 34/10-36, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1940
# Well: 34/10-37, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2431
# Well: 34/10-38 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2517
# Well: 34/10-41 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3085
# Well: 34/10-42 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3816
# Well: 34/10-43 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4247
# Well: 34/10-44 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4422
# Well: 34/10-47 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4640
# Well: 34/10-49 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5282
# Well: 34/10-52 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6657
# Well: 34/10-52 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6147
# Well: 34/10-54 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7254
# Well: 34/11-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2866
# Well: 34/11-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3314
# Well: 35/1-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4541
# Well: 35/1-2 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6427
# Well: 35/2-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5135
# Well: 35/2-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6084
# Well: 35/2-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6921
# Well: 35/3-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/432
# Well: 35/3-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/136
# Well: 35/3-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/491
# Well: 35/3-4, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/219
# Well: 35/3-6, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4492
# Well: 35/3-7 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6154
# Well: 35/10-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2783
# Well: 35/10-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3719
# Well: 35/10-7 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9404
# Well: 36/1-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/436
# Well: 36/1-4 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9430
# Well: 6204/10-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2666
# Well: 6204/10-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2952
# Well: 6204/11-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/2205
# Well: 6204/11-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3249
# Well: 6204/11-3, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/9111
# Well: 6305/9-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/4297
# Well: 6305/12-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/1808
# Well: 6306/5-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3060
# Well: 6407/6-7 S, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/6100
# Well: 6407/8-4 A, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/5814
# Well: 6407/9-5, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/492
# Well: 6407/12-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/3781
# Well: 6610/7-2, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/26
# Well: 6610/10-1, URL: https://factpages.sodir.no/en/wellbore/PageView/Exploration/All/7091
#
# Wells from CSV not found in Factpages:
# 34/4-U-3
# 34/7-U-27
# 30/2-U-1
# 34/10-A-3 H

# %% [markdown]
# ## 1.3 Scraping wellbore history from the wells in "well list.csv" (all the wells in our area) and saves as "wellbore_history.txt".

# %%
def scrape_wellbore_history(url):
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    elements = soup.select('html > body > main > div > div:nth-of-type(2) > ul > li:nth-of-type(2) > *')
    processed_text = ""
    for element in elements:
        if element.name == 'span' and element.get('style', '') == 'font-weight:700;':
            processed_text += f"\n\nHeader: {element.text}\n"
        else:
            processed_text += element.text + ' '
    return processed_text.strip()

# Read existing content from the file
existing_content = ""
try:
    with open('wellbore_history.txt', 'r', encoding='utf-8') as file:
        existing_content = file.read()
except FileNotFoundError:
    # If the file does not exist, proceed as it will be created later
    pass

# Initialize a list to hold data for printing and writing, if not already fetched
well_data = []

# Fetch data once and store it, if not already in the file
for well_name, well_url in well_list:
    if f"Well: {well_name}" not in existing_content:
        additional_info = scrape_wellbore_history(well_url)
        well_data.append((well_name, additional_info))
        # Pause the execution for a specified number of seconds to avoid overloading the server
        time.sleep(4) # Being polite to the server :)

# Write new data to the file, if any
with open('wellbore_history.txt', 'a', encoding='utf-8') as file:  # Note the 'a' mode for appending
    for well_name, additional_info in well_data:
        text_to_write = f"Well: {well_name}\n{additional_info}\n" + "-" * 50 + "\n"
        if text_to_write.strip() not in existing_content:
            file.write(text_to_write)

# Check if the file exists after executing the script and print a message
if os.path.exists(file_path):
    print("wellbore_history.txt already exists")

# Note: The content check is done before scraping to avoid unnecessary server requests.
# This implementation assumes that "Well: {well_name}" is a unique identifier for each entry.
# Out:
# wellbore_history.txt already exists

# %% [markdown]
# ## 1.4 Scraping General Information table from the Factpages

# %%
def scrape_table_data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    row_data = []

    table = soup.find('table', class_='general-info-table')
    if table:
        rows = table.find_all('tr')[1:]  # Skip header row
        
        # List of row indices to be excluded
        excluded_rows_indices = [4]  # Example: Exclude row 4 (zero-indexed)
        
        for i, row in enumerate(rows):
            if i not in excluded_rows_indices:  # Check if the current row index is not in the list of excluded indices
                cells = row.find_all('td')
                if len(cells) == 2:
                    # Manually navigate and clean the cells[0] content
                    for content in cells[0].contents:
                        if isinstance(content, Tag) and (content.name == 'div' and 'uk-drop' in content.get('class', [])):
                            content.decompose()  # Remove the matching div and its contents
                        if isinstance(content, Tag) and content.name == 'button':
                            content.decompose()  # Remove the button and its contents
                    
                    attribute = ''.join(cells[0].stripped_strings)  # Reconstruct attribute text without unwanted parts

                    # Extract value
                    value_div = cells[1].find('div')
                    if value_div:
                        value = value_div.get_text(strip=True)
                    else:
                        value = cells[1].text.strip()

                    row_data.append([attribute, value])

    return row_data

def write_to_csv(well_name, data, file_path):
    file_exists = os.path.isfile(file_path)
    with open(file_path, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        if not file_exists:
            writer.writerow(['Attribute', 'Value'])  # Adjust column names as necessary
        for row in data:
            writer.writerow(row)

def write_to_txt(well_name, data, file_path):
    with open(file_path, 'a', newline='', encoding='utf-8') as txtfile:
        txtfile.write(f"{well_name}\n")
        for row in data:
            txtfile.write(f"{row[0]}: {row[1]}\n")
        txtfile.write('\n')

def check_well_exists(well_name, file_path):
    if not os.path.isfile(file_path):
        return False
    with open(file_path, 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            if well_name in row:
                return True
    return False

file_path_csv = 'general_information.csv'
file_path_txt = 'general_information.txt'

for well_name, well_url in well_list[:2]:
    if check_well_exists(well_name, file_path_csv):
        print(f"Data for {well_name} already exists in CSV - skipped")
    else:
        data = scrape_table_data(well_url)
        write_to_csv(well_name, data, file_path_csv)
        print(f"Data for {well_name} written to CSV.")

    if check_well_exists(well_name, file_path_txt):
        print(f"Data for {well_name} already exists in TXT - skipped")
    else:
        data = scrape_table_data(well_url)
        write_to_txt(well_name, data, file_path_txt)
        print(f"Data for {well_name} written to TXT.")

    time.sleep(2) # Being polite to the server again :)

# Read the CSV file using Pandas and print the table
df = pd.read_csv(file_path_csv)
print(df)
# Out:
# Data for 30/2-1 already exists in CSV - skipped
# Data for 30/2-1 already exists in TXT - skipped
# Data for 30/2-2 already exists in CSV - skipped
# Data for 30/2-2 already exists in TXT - skipped
#          Attribute             Value
# 0    Wellbore name            30/2-1
# 1             Type       EXPLORATION
# 2          Purpose           WILDCAT
# 3           Status               P&A
# 4        Main area         NORTH SEA
# ..             ...               ...
# 75      EW degrees  2° 39' 51.65'' E
# 76      NS UTM [m]        6744240.64
# 77      EW UTM [m]         481749.07
# 78        UTM zone                31
# 79  NPDID wellbore               457
#
# [80 rows x 2 columns]

# %% [markdown]
# ## Test
